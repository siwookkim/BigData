# %%
import my_module.naver_api_crawler as crawler

# %%
crawler.get1000Result("외식쿠폰")
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# [{'title': '현대백화점 충청점 빕스 x 지마켓 <b>쿠폰</b>으로 <b>외식</b> ♬♩♪',
#   'link': 'http://blog.naver.com/fall1115?Redirect=Log&amp;logNo=221408870407',
#   'description': '현백 충청점 빕스 x 지마켓 <b>쿠폰</b>으로 <b>외식</b>하기 지난주 일요일 남편이 청주에 상담이 3건이 잡혔었죠 딸아이는 시험공부 한다고 못 따라나서고 아들과 저랑만 따라나섰어요 남편이 고객님들과 상담할 동안... ',
#   'bloggername': '창앤블라인드의 중문. 커튼. 블라인드 043.236.6341',
#   'bloggerlink': 'http://blog.naver.com/fall1115',
#   'postdate': '20181129'},
#  {'title': '가족들과 함께 TGIF <b>외식</b> (할인 <b>쿠폰</b> 받는 법)',
#   'link': 'http://blog.naver.com/eomnoe?Redirect=Log&amp;logNo=221279724152',
#   'description': '저희끼리 이런저런 <b>쿠폰</b>을 살펴보고 5인에 알맞게 아주 골-고루 주문을 해봤어요! 파노라마로 한번... 잊지마세용 TGIF RIDAY 할인 <b>쿠폰</b> 받는 법! 1. OK 캐시백 어플 다운받기 2. 검색창에 TGIF 검색 3. <b>쿠폰</b>받기... ',
#   'bloggername': '로렌의하루',
# ...

# %%
result1 = crawler.get1000Result("강남역 맛집")
print(result1)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
result2 = crawler.get1000Result("강남역 찻집")
result2
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# [{'title': '<b>강남역</b> 카페 &lt;춘화당&gt; 차 종류가 다양한 <b>찻집</b>',
#   'link': 'http://blog.naver.com/h45w6?Redirect=Log&amp;logNo=221428765754',
#   'description': '#<b>강남역</b>카페 / #<b>강남</b><b>찻집</b> 춘화당 *주소: 서울 <b>강남</b>구 <b>강남</b>대로110길 62 (<b>강남역</b> 11번출구 또는 신논현역 4번출구) *연락처: 02-567-6663 *영업시간 월-금: 오후 3시~ 밤 12시 토-일: 오후 1시~ 밤 10시 (목요일 휴무) *커피... ',
#   'bloggername': '쟈쟈졔의 여행 라이프',
#   'bloggerlink': 'http://blog.naver.com/h45w6',
#   'postdate': '20181228'},
#  {'title': '20180119_<b>강남역</b>_<b>찻집</b>_라포레',
#   'link': 'http://blog.naver.com/chanyu_kim79?Redirect=Log&amp;logNo=221314971888',
#   'description': '커피집이 많은 골목을 돌아다니다가 들어간 <b>찻집</b>. 라포레. 이 곳은 무려 대학원 시절 한 번 방문한 적이... 클래식한 분위기의 <b>찻집</b>임. 밤시간이라 커피 마시기에는 부담스러워서 차를 골랐음. 라즈베리차였나???... ',
#   'bloggername': '신명나게 살기',
# ...

# %%
import json

# %%
list = []
list = result1+result2

# %%
file = open("./gangnam2.json", "w+")
file.write(json.dumps(result1+result2))
# Out:
# 1741302
